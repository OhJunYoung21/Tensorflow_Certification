# %% [markdown]
# <a href="https://colab.research.google.com/github/OhJunYoung21/Tensorflow_Certification/blob/main/Untitled28.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
print(tf.__version__)
# Out:
# 2.14.0

# %%
# Build a simple Sequential model
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
# Compile the model
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %%
# Train the model
model.fit(xs, ys, epochs=700)
# Out:
# Epoch 1/700
# 1/1 [==============================] - 1s 823ms/step - loss: 16.9323
# Epoch 2/700
# 1/1 [==============================] - 0s 38ms/step - loss: 13.5721
# Epoch 3/700
# 1/1 [==============================] - 0s 25ms/step - loss: 10.9234
# Epoch 4/700
# 1/1 [==============================] - 0s 27ms/step - loss: 8.8344
# Epoch 5/700
# 1/1 [==============================] - 0s 15ms/step - loss: 7.1859
# Epoch 6/700
# 1/1 [==============================] - 0s 35ms/step - loss: 5.8842
# Epoch 7/700
# 1/1 [==============================] - 0s 12ms/step - loss: 4.8553
# Epoch 8/700
# 1/1 [==============================] - 0s 17ms/step - loss: 4.0411
# Epoch 9/700
# 1/1 [==============================] - 0s 19ms/step - loss: 3.3961
# Epoch 10/700
# 1/1 [==============================] - 0s 15ms/step - loss: 2.8841
# Epoch 11/700
# 1/1 [==============================] - 0s 22ms/step - loss: 2.4770
# Epoch 12/700
# ...

# %%
print(model.predict([10.0]))
# Out:
# 1/1 [==============================] - 0s 280ms/step
# [[18.997646]]
